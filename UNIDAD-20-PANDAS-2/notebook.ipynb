# %% [markdown]
# # UNIDAD 20 - PANDAS 2
#
# Utilizando los conceptos aprendidos en el módulo 20 - Datos con
# Pandas II, resolver el siguiente ejercicio.
#
# Desarrollar una aplicación que realice la siguientes tareas:
#
# 1. Conectarse a la [url](http://winterolympicsmedals.com/medals.csv) que contiene el archivo CSV de medallas
# 2. Descargar los datos y obtener un sub dataset que contenga a
# todas las medallas de oro (Gold) Estados Unidos (USA) a partir del
# año 1950.
# 3. Crear una base de datos “olympics” en SQLite y la tabla “medals”.
# 4. Guardar en la base de datos. los datos generados en el sub
# dataset.
# 5. Consultar la base de datos y validar que los datos se hayan
# cargado correctamente.

# %% [markdown]
# ---

# %% [markdown]
# 1. Conectarse a la [url](http://winterolympicsmedals.com/medals.csv) que contiene el archivo CSV de medallas

# %%
import pandas as pd 

url_csv_medallas = 'http://winterolympicsmedals.com/medals.csv'

df_medallas = pd.read_csv(url_csv_medallas)

df_medallas
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# 4               M    Gold
# ...           ...     ...
# 2306            M  Silver
# 2307            W    Gold
# 2308            W  Silver
# 2309            M    Gold
# 2310            W  Silver
#
# [2311 rows x 8 columns]

# %% [markdown]
# ---

# %% [markdown]
# 2. Descargar los datos y obtener un sub dataset que contenga a
# todas las medallas de oro (Gold) Estados Unidos (USA) a partir del
# año 1950.

# %%
df_medallas_desde_1950 = df_medallas[(df_medallas['Medal'] == 'Gold') 
                         & (df_medallas['Year'] >= 1950) 
                         & (df_medallas['NOC'] == 'CAN')]
                         
df_medallas_desde_1950
# Out:
#       Year            City       Sport       Discipline  NOC         Event  \
# 259   1952            Oslo  Ice Hockey       Ice Hockey  CAN    ice hockey
# 398   1960    Squaw Valley     Skating   Figure skating  CAN         pairs
# 399   1960    Squaw Valley      Skiing    Alpine Skiing  CAN        slalom
# 483   1964       Innsbruck   Bobsleigh        Bobsleigh  CAN      four-man
# 586   1968        Grenoble      Skiing    Alpine Skiing  CAN  giant slalom
# 793   1976       Innsbruck      Skiing    Alpine Skiing  CAN  giant slalom
# 1013  1984        Sarajevo     Skating    Speed skating  CAN         1000m
# 1014  1984        Sarajevo     Skating    Speed skating  CAN         1500m
# 1291  1992     Albertville     Skating   Short Track S.  CAN   3000m relay
# 1293  1992     Albertville      Skiing    Alpine Skiing  CAN      downhill
# 1449  1994     Lillehammer    Biathlon         Biathlon  CAN          15km
# 1450  1994     Lillehammer    Biathlon         Biathlon  CAN         7.5km
# 1461  1994     Lillehammer      Skiing   Freestyle Ski.  CAN        moguls
# 1642  1998          Nagano   Bobsleigh        Bobsleigh  CAN       two-man
# 1644  1998          Nagano     Curling          Curling  CAN       curling
# 1649  1998          Nagano     Skating   Short Track S.  CAN   5000m relay
# 1650  1998          Nagano     Skating   Short Track S.  CAN          500m
# 1654  1998          Nagano     Skating    Speed skating  CAN          500m
# 1656  1998          Nagano      Skiing        Snowboard  CAN  giant-slalom
# 1850  2002  Salt Lake City  Ice Hockey       Ice Hockey  CAN    ice hockey
# 1851  2002  Salt Lake City  Ice Hockey       Ice Hockey  CAN    ice hockey
# 1852  2002  Salt Lake City     Skating   Figure skating  CAN         pairs
# 1856  2002  Salt Lake City     Skating   Short Track S.  CAN   5000m relay
# 1857  2002  Salt Lake City     Skating   Short Track S.  CAN          500m
# 1861  2002  Salt Lake City     Skating    Speed skating  CAN          500m
# 1862  2002  Salt Lake City      Skiing  Cross Country S  CAN   5km pursuit
# 2087  2006           Turin   Bobsleigh         Skeleton  CAN    individual
# 2090  2006           Turin     Curling          Curling  CAN       curling
# 2092  2006           Turin  Ice Hockey       Ice Hockey  CAN    ice hockey
# 2099  2006           Turin     Skating    Speed skating  CAN         1500m
# 2103  2006           Turin     Skating    Speed skating  CAN         5000m
# 2106  2006           Turin      Skiing  Cross Country S  CAN  Sprint 1.5km
# 2108  2006           Turin      Skiing   Freestyle Ski.  CAN        moguls
#
#      Event gender Medal
# 259             M  Gold
# 398             X  Gold
# 399             W  Gold
# 483             M  Gold
# 586             W  Gold
# 793             W  Gold
# 1013            M  Gold
# 1014            M  Gold
# 1291            W  Gold
# 1293            W  Gold
# 1449            W  Gold
# 1450            W  Gold
# 1461            M  Gold
# 1642            M  Gold
# 1644            W  Gold
# 1649            M  Gold
# 1650            W  Gold
# 1654            W  Gold
# 1656            M  Gold
# 1850            M  Gold
# 1851            W  Gold
# 1852            X  Gold
# 1856            M  Gold
# 1857            M  Gold
# 1861            W  Gold
# 1862            W  Gold
# 2087            M  Gold
# 2090            M  Gold
# 2092            W  Gold
# 2099            W  Gold
# 2103            W  Gold
# 2106            W  Gold
# 2108            W  Gold

# %% [markdown]
# ---

# %% [markdown]
# 3. Crear una base de datos “olympics” en SQLite y la tabla “medals”.

# %%
import sqlite3

conexion = sqlite3.connect("olympics.db")

query_create_table = """ CREATE TABLE IF NOT EXISTS medals(
                            id integer primary key autoincrement,
                            Year int,	
                            City text,	
                            Sport text,	
                            Discipline text,	
                            NOC text,	
                            Event text,	
                            'Event gender' text,	
                            Medal text    
                        )
                     """
conexion.execute(query_create_table)

# %% [markdown]
# ---

# %% [markdown]
# 4. Guardar en la base de datos. los datos generados en el sub
# dataset.

# %%
df_medallas_desde_1950.to_sql('medals', con=conexion, if_exists='replace', index=False)
# Out:
# 33

# %% [markdown]
# ---

# %% [markdown]
# 5. Consultar la base de datos y validar que los datos se hayan
# cargado correctamente.

# %%
df = pd.read_sql_query('SELECT * FROM medals', con=conexion)
df
# Out:
#     Year            City       Sport       Discipline  NOC         Event  \
# 0   1952            Oslo  Ice Hockey       Ice Hockey  CAN    ice hockey
# 1   1960    Squaw Valley     Skating   Figure skating  CAN         pairs
# 2   1960    Squaw Valley      Skiing    Alpine Skiing  CAN        slalom
# 3   1964       Innsbruck   Bobsleigh        Bobsleigh  CAN      four-man
# 4   1968        Grenoble      Skiing    Alpine Skiing  CAN  giant slalom
# 5   1976       Innsbruck      Skiing    Alpine Skiing  CAN  giant slalom
# 6   1984        Sarajevo     Skating    Speed skating  CAN         1000m
# 7   1984        Sarajevo     Skating    Speed skating  CAN         1500m
# 8   1992     Albertville     Skating   Short Track S.  CAN   3000m relay
# 9   1992     Albertville      Skiing    Alpine Skiing  CAN      downhill
# 10  1994     Lillehammer    Biathlon         Biathlon  CAN          15km
# 11  1994     Lillehammer    Biathlon         Biathlon  CAN         7.5km
# 12  1994     Lillehammer      Skiing   Freestyle Ski.  CAN        moguls
# 13  1998          Nagano   Bobsleigh        Bobsleigh  CAN       two-man
# 14  1998          Nagano     Curling          Curling  CAN       curling
# 15  1998          Nagano     Skating   Short Track S.  CAN   5000m relay
# 16  1998          Nagano     Skating   Short Track S.  CAN          500m
# 17  1998          Nagano     Skating    Speed skating  CAN          500m
# 18  1998          Nagano      Skiing        Snowboard  CAN  giant-slalom
# 19  2002  Salt Lake City  Ice Hockey       Ice Hockey  CAN    ice hockey
# 20  2002  Salt Lake City  Ice Hockey       Ice Hockey  CAN    ice hockey
# 21  2002  Salt Lake City     Skating   Figure skating  CAN         pairs
# 22  2002  Salt Lake City     Skating   Short Track S.  CAN   5000m relay
# 23  2002  Salt Lake City     Skating   Short Track S.  CAN          500m
# 24  2002  Salt Lake City     Skating    Speed skating  CAN          500m
# 25  2002  Salt Lake City      Skiing  Cross Country S  CAN   5km pursuit
# 26  2006           Turin   Bobsleigh         Skeleton  CAN    individual
# 27  2006           Turin     Curling          Curling  CAN       curling
# 28  2006           Turin  Ice Hockey       Ice Hockey  CAN    ice hockey
# 29  2006           Turin     Skating    Speed skating  CAN         1500m
# 30  2006           Turin     Skating    Speed skating  CAN         5000m
# 31  2006           Turin      Skiing  Cross Country S  CAN  Sprint 1.5km
# 32  2006           Turin      Skiing   Freestyle Ski.  CAN        moguls
#
#    Event gender Medal
# 0             M  Gold
# 1             X  Gold
# 2             W  Gold
# 3             M  Gold
# 4             W  Gold
# 5             W  Gold
# 6             M  Gold
# 7             M  Gold
# 8             W  Gold
# 9             W  Gold
# 10            W  Gold
# 11            W  Gold
# 12            M  Gold
# 13            M  Gold
# 14            W  Gold
# 15            M  Gold
# 16            W  Gold
# 17            W  Gold
# 18            M  Gold
# 19            M  Gold
# 20            W  Gold
# 21            X  Gold
# 22            M  Gold
# 23            M  Gold
# 24            W  Gold
# 25            W  Gold
# 26            M  Gold
# 27            M  Gold
# 28            W  Gold
# 29            W  Gold
# 30            W  Gold
# 31            W  Gold
# 32            W  Gold

# %% [markdown]
# ---
