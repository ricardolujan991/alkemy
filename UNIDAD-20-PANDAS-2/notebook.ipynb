# %% [markdown]
# # UNIDAD 20 - PANDAS 2
#
# Utilizando los conceptos aprendidos en el módulo 20 - Datos con
# Pandas II, resolver el siguiente ejercicio.
#
# Desarrollar una aplicación que realice la siguientes tareas:
#
# 1. Conectarse a la [url](http://winterolympicsmedals.com/medals.csv) que contiene el archivo CSV de medallas
# 2. Descargar los datos y obtener un sub dataset que contenga a
# todas las medallas de oro (Gold) Estados Unidos (USA) a partir del
# año 1950.
# 3. Crear una base de datos “olympics” en SQLite y la tabla “medals”.
# 4. Guardar en la base de datos. los datos generados en el sub
# dataset.
# 5. Consultar la base de datos y validar que los datos se hayan
# cargado correctamente.

# %% [markdown]
# ---

# %% [markdown]
# 1. Conectarse a la [url](http://winterolympicsmedals.com/medals.csv) que contiene el archivo CSV de medallas

# %%
import pandas as pd 

url_csv_medallas = 'http://winterolympicsmedals.com/medals.csv'

df_medallas = pd.read_csv(url_csv_medallas)

df_medallas
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# 4               M    Gold
# ...           ...     ...
# 2306            M  Silver
# 2307            W    Gold
# 2308            W  Silver
# 2309            M    Gold
# 2310            W  Silver
#
# [2311 rows x 8 columns]

# %% [markdown]
# ---

# %% [markdown]
# 2. Descargar los datos y obtener un sub dataset que contenga a
# todas las medallas de oro (Gold) Estados Unidos (USA) a partir del
# año 1950.

# %%
df_medallas_desde_1950 = df_medallas[(df_medallas['Medal'] == 'Gold') 
                         & (df_medallas['Year'] >= 1950)]
                         
df_medallas_desde_1950
# Out:
#       Year   City       Sport       Discipline  NOC            Event  \
# 254   1952   Oslo      Skiing    Alpine Skiing  AUT         downhill
# 258   1952   Oslo      Skiing    Alpine Skiing  AUT           slalom
# 259   1952   Oslo  Ice Hockey       Ice Hockey  CAN       ice hockey
# 262   1952   Oslo      Skiing  Cross Country S  FIN             10km
# 266   1952   Oslo      Skiing  Cross Country S  FIN     4x10km relay
# ...    ...    ...         ...              ...  ...              ...
# 2301  2006  Turin      Skiing    Alpine Skiing  USA  Alpine combined
# 2302  2006  Turin      Skiing    Alpine Skiing  USA     giant slalom
# 2305  2006  Turin      Skiing        Snowboard  USA        Half-pipe
# 2307  2006  Turin      Skiing        Snowboard  USA        Half-pipe
# 2309  2006  Turin      Skiing        Snowboard  USA  Snowboard Cross
#
#      Event gender Medal
# 254             W  Gold
# 258             M  Gold
# 259             M  Gold
# 262             W  Gold
# 266             M  Gold
# ...           ...   ...
# 2301            M  Gold
# 2302            W  Gold
# 2305            M  Gold
# 2307            W  Gold
# 2309            M  Gold
#
# [691 rows x 8 columns]

# %% [markdown]
# ---

# %% [markdown]
# 3. Crear una base de datos “olympics” en SQLite y la tabla “medals”.

# %%
import sqlite3

conexion = sqlite3.connect("olympics.db")

query_create_table = """ CREATE TABLE IF NOT EXISTS medals(
                            id integer primary key autoincrement,
                            Year int,	
                            City text,	
                            Sport text,	
                            Discipline text,	
                            NOC text,	
                            Event text,	
                            'Event gender' text,	
                            Medal text    
                        )
                     """
conexion.execute(query_create_table)

# %% [markdown]
# ---

# %% [markdown]
# 4. Guardar en la base de datos. los datos generados en el sub
# dataset.

# %%
df_medallas_desde_1950.to_sql('medals', con=conexion, if_exists='replace', index=False)
# Out:
# 691

# %% [markdown]
# ---

# %% [markdown]
# 5. Consultar la base de datos y validar que los datos se hayan
# cargado correctamente.

# %%
df = pd.read_sql_query('SELECT * FROM medals', con=conexion)
df
# Out:
#      Year   City       Sport       Discipline  NOC            Event  \
# 0    1952   Oslo      Skiing    Alpine Skiing  AUT         downhill
# 1    1952   Oslo      Skiing    Alpine Skiing  AUT           slalom
# 2    1952   Oslo  Ice Hockey       Ice Hockey  CAN       ice hockey
# 3    1952   Oslo      Skiing  Cross Country S  FIN             10km
# 4    1952   Oslo      Skiing  Cross Country S  FIN     4x10km relay
# ..    ...    ...         ...              ...  ...              ...
# 686  2006  Turin      Skiing    Alpine Skiing  USA  Alpine combined
# 687  2006  Turin      Skiing    Alpine Skiing  USA     giant slalom
# 688  2006  Turin      Skiing        Snowboard  USA        Half-pipe
# 689  2006  Turin      Skiing        Snowboard  USA        Half-pipe
# 690  2006  Turin      Skiing        Snowboard  USA  Snowboard Cross
#
#     Event gender Medal
# 0              W  Gold
# 1              M  Gold
# 2              M  Gold
# 3              W  Gold
# 4              M  Gold
# ..           ...   ...
# 686            M  Gold
# 687            W  Gold
# 688            M  Gold
# 689            W  Gold
# 690            M  Gold
#
# [691 rows x 8 columns]

# %% [markdown]
# ---
